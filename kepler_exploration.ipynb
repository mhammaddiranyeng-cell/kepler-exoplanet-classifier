# %% [markdown]
# # Kepler Objects of Interest (KOI) Dataset Exploration
#
# This notebook provides an interactive exploration of the NASA Kepler Objects of Interest dataset.
#
# ## Dataset Overview
# - **Source**: NASA Exoplanet Archive
# - **Total entries**: 9,564 KOI objects
# - **Key columns**: kepoi_name, koi_period, koi_duration, koi_depth, koi_prad, koi_srad, koi_teq, koi_disposition
# - **Disposition types**: CONFIRMED, CANDIDATE, FALSE POSITIVE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")
# %matplotlib inline

# %%
# Load the dataset
df = pd.read_csv('kepler_koi_dataset.csv')

print(f"Dataset Shape: {df.shape}")
print(f"Total KOI entries: {len(df):,}")

# Display basic info
df.info()
